# %%
'''Question no1: ake a calculator using Python with addition , subtraction ,
multiplication ,division and power.'''


def calculate():
    operation = input('''
Please enter number for operation you would like to perform:
1. for addition
2. for subtraction
3. for multiplication
4. for division
5. for power 
''')

    number_1 = int(input('Please enter the first number: '))
    number_2 = int(input('Please enter the second number: '))

    if operation == '1':
        print('{} + {} = '.format(number_1, number_2))
        print(number_1 + number_2)

    elif operation == '2':
        print('{} - {} = '.format(number_1, number_2))
        print(number_1 - number_2)

    elif operation == '3':
        print('{} * {} = '.format(number_1, number_2))
        print(number_1 * number_2)

    elif operation == '4':
        print('{} / {} = '.format(number_1, number_2))
        print(number_1 / number_2)

    elif operation == '5':
        print('{} ** {} = '.format(number_1, number_2))
        print(number_1 ** number_2) 

    else:
        print('You have not typed a valid number:') 

calculate()
# Out:
# Please enter number for operation you would like to perform:
# 1. for addition
# 2. for subtraction
# 3. for multiplication
# 4. for division
# 5. for power
# 5
# Please enter the first number: 2
# Please enter the second number: 3
# 2 ** 3 =
# 8

# %%
'''Question no:2 Write a program to check if there is any numeric value in list using for
loop. '''

list = ["hello!","I,m","sehrish", "gulzar", 621, "thank you"]
for num in list:
    if type(num) == int:
        print(num)
# Out:
# 621

# %%
'''Question no 3: Write a Python script to add a key to a dictionary. '''

key=int(input("Enter the key (int) to be added:"))
value=int(input("Enter the value for the key to be added:"))
d={}
d.update({key:value})
print("Updated dictionary is:")
print(d)
# Out:
# Enter the key (int) to be added:8
# Enter the value for the key to be added:0
# Updated dictionary is:
# {8: 0}

# %%
'''Question no 4:Write a Python program to sum all the numeric items in a dictionary.'''


def returnSum(dict):

    sum = 0
    for i in dict.values():
        sum = sum + i

    return sum


dict = {'a': 100, 'b':200, 'c':300,'d':400,'e':500,'f':600,}
print("Sum :", returnSum(dict))
# Out:
# Sum : 2100

# %%
''' Question no 5: Write a program to identify duplicate values from list.'''

l=[1,2,3,4,5,2,3,4,7,9,5,10,10]
l1=[]
for i in l:
    if i not in l1:
        l1.append(i)
    else:
        print(i,end=' ')
# Out:
# 2 3 4 5 10

# %%
''' Question no 6: Write a Python script to check if a given key already exists in a
dictionary'''
d = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
def is_key_present(x):
    if x in d:
        print('Key is present in the dictionary')
    else:
        print('Key is not present in the dictionary')
is_key_present(5)
is_key_present(9)
# Out:
# Key is present in the dictionary
# Key is not present in the dictionary
